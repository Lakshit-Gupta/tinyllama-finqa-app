# %%
# !pip install -q transformers datasets peft accelerate trl

# %%
# !uv pip install bitsandbytes
# Out:
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 123ms

# %%
from datasets import load_dataset

dataset = load_dataset("virattt/financial-qa-10K", split="train")
dataset = dataset.shuffle()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/419 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7000 [00:00<?, ? examples/s]

# %%
def format_example(example):
    return {
        "text": f"### Question:\n{example['question']}\n\n### Answer:\n{example['answer']}"
    }

dataset = dataset.map(format_example)
# Out:
# Map:   0%|          | 0/7000 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer

model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token

def tokenize_function(example):
    return tokenizer(
        example["text"],
        padding="max_length",
        truncation=True,
        max_length=512,
        return_tensors="pt"
    )

tokenized_dataset = dataset.map(tokenize_function, batched=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# Map:   0%|          | 0/7000 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForCausalLM
from peft import LoraConfig, get_peft_model, TaskType

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    load_in_4bit=True,
    device_map="auto"
)
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# trainable params: 1,126,400 || all params: 1,101,174,784 || trainable%: 0.1023

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

# %% [markdown]
# Made changes.

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./tinyllama-finqa",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    num_train_epochs=3,
    learning_rate=2e-4,
    fp16=True,
    logging_steps=10,
    save_steps=100,
    save_total_limit=1,
    report_to="none"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    data_collator=data_collator,
)
trainer.train()
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:463: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
#     <div>
#
#       <progress value='2625' max='2625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2625/2625 1:14:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.037600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.740300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.627200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.385100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.490600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.445600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.483400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.375400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.412800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.306800</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.445000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.350300</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.304200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.314400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.266700</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.337400</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.271400</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.341300</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.346900</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.361500</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.363200</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.276300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.340900</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.352300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.326000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.253600</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.390000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.370100</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.412200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.284200</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.295300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.280000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.304500</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.287100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.230500</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.346600</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.396500</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.320200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>1.311300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.343900</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.376600</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.249800</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.335500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.236900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.274200</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.282700</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.240700</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.224800</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.337700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.264600</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.270700</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.397600</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>1.245300</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>1.107000</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.210600</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>1.317300</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>1.295800</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>1.253300</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1.277800</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.204400</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>1.263500</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>1.227500</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>1.298200</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>1.281700</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.290000</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>1.341500</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>1.345300</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>1.283000</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>1.276800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.275900</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>1.354200</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>1.341600</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>1.249800</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>1.227400</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.238700</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>1.395600</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>1.270800</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>1.295400</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>1.209000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.261400</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>1.323600</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>1.285300</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>1.215600</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>1.233200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.325900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>1.233800</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>1.248400</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>1.248200</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>1.248900</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.295000</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>1.289100</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>1.294600</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>1.197200</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>1.363500</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.185400</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>1.236200</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>1.359600</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>1.341700</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>1.164600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.311000</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>1.260100</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>1.214300</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>1.314400</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>1.285200</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>1.228600</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>1.146900</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>1.249900</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>1.202300</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>1.272200</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.243400</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>1.266900</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>1.262400</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>1.198500</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>1.220100</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>1.196600</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>1.297400</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>1.249700</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>1.270400</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>1.269600</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.199100</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>1.248100</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>1.234300</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>1.283800</td>
#     </tr>
#     <tr>
#       <td>1
# TrainOutput(global_step=2625, training_loss=1.2552065607706706, metrics={'train_runtime': 4444.2887, 'train_samples_per_second': 4.725, 'train_steps_per_second': 0.591, 'total_flos': 6.6811129233408e+16, 'train_loss': 1.2552065607706706, 'epoch': 3.0})

# %%
The Orvilletokenizer.save_pretrained("./tinyllama-finqa-lora")
# Out:
# ('./tinyllama-finqa-lora/tokenizer_config.json',
#  './tinyllama-finqa-lora/special_tokens_map.json',
#  './tinyllama-finqa-lora/chat_template.jinja',
#  './tinyllama-finqa-lora/tokenizer.model',
#  './tinyllama-finqa-lora/added_tokens.json',
#  './tinyllama-finqa-lora/tokenizer.json')
